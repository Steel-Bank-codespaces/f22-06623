# %% [markdown]
# See https://ipywebrtc.readthedocs.io/en/latest/index.html

# %% [markdown]
# # Record audio
#
# https://ipywebrtc.readthedocs.io/en/latest/api.html#ipywebrtc.webrtc.AudioRecorder
#
# You need to do these in three separate cells I think.

# %%
from ipywebrtc import AudioRecorder, CameraStream

camera = CameraStream(constraints={'audio': True,' video': False})
recorder = AudioRecorder(stream=camera)
recorder
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'audio': True, 'video': …

# %%
recorder.save('test.wav')

# %%
from IPython.display import Audio
Audio('test.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
